# %% [markdown]
# # 🗂 Classification Problems and Common Use Cases
#
# ---
#
# ## ❓ What is Classification?
# Classification is a **supervised learning task** where the goal is to **predict discrete class labels (categories)** based on input features.
# - The model learns from **labeled data** and assigns new data points to one or more categories.
# - Widely used in areas like **image recognition, text processing, and medical diagnostics**.
#
# ---
#
# ## 🔢 Types of Classification
#
# ### 1️⃣ Binary Classification
# - Predicts **one of two possible classes**.
# - 📌 **Example**: Spam vs. Not Spam (email filtering).
#
# ### 2️⃣ Multi-Class Classification
# - Predicts **one of more than two classes**.
# - 📌 **Example**: Classifying images into **cats, dogs, or birds**.
#
# ### 3️⃣ Multi-Label Classification
# - Assigns **multiple labels** to a single instance.
# - 📌 **Example**: A news article tagged with multiple topics like **politics, economy, and health**.
#
# ---
#
# ## 🌐 Common Use Cases
#
# | **Domain**                 | **Examples**                         |
# |-----------------------------|-------------------------------------|
# | 🏥 **Healthcare**           | Disease diagnosis, medical image analysis |
# | 💰 **Finance**              | Fraud detection, credit scoring       |
# | 🛒 **Retail**               | Customer segmentation, product recommendation |
# | 📝 **Natural Language Processing** | Sentiment analysis, text classification |
# | 🚗 **Autonomous Systems**   | Object recognition, lane detection    |

# %% [markdown]
# # 🔑 Logistic Regression for Binary Classification
#
# ---
#
# ## ❓ What is Logistic Regression?
# Logistic Regression is a **statistical method** used for **predicting binary outcomes** (two possible classes).
# - It estimates the **probability** that a given input point belongs to a **particular class**.
# - Commonly used for **classification tasks** such as spam detection, disease diagnosis, and churn prediction.
#
# ---
#
# ## 🧮 The Logistic Regression Model
#
# ### 📐 Equation
# Logistic regression applies the **sigmoid function** to a linear equation:
#
# \[
# P(y=1 \mid x) = \sigma(z) = \frac{1}{1 + e^{-z}}
# \]
#
# Where the linear combination \( z \) is:
#
# \[
# z = \beta_0 + \beta_1 x_1 + \beta_2 x_2 + \dots + \beta_n x_n
# \]
#
# ### 🧩 Components
# - **P(y=1 ∣ x)** – Probability that the input \(x\) belongs to the **positive class**.
# - **σ(z)** – Sigmoid (logistic) function that **maps values** between **0 and 1**.
# - **z** – Linear combination of **input features** and **model coefficients** \((\beta_0, \beta_1, \dots, \beta_n)\).
#
# ---
#
# ## 📌 Key Insight
# - Outputs a **probability** rather than a direct class label.
# - A **threshold** (commonly 0.5) is applied to assign the final class.
# - Useful for problems where **probabilities** are more informative than binary predictions.

# %% [markdown]
# # 📊 Logistic Regression for Binary Classification
#
# ---
#
# ## 🔗 The Logistic Regression Model
#
# ### 🌀 Sigmoid Function
# - **Purpose:** Maps the output \( z \) to a range between **0 and 1**.
# - **Classification Rule:**
#   \[
#   \text{If } P(y=1 \mid x) \geq 0.5, \text{ predict class 1; otherwise, predict class 0.}
#   \]
#
# ---
#
# ### ✂️ Decision Boundary
# - **Definition:** The **threshold** used to classify instances.
# - **Default:** **0.5**, but it can be **adjusted**:
#   - Lower threshold → **Higher recall** (catch more positives, but risk false positives).
#   - Higher threshold → **Higher precision** (fewer false positives, but may miss positives).
#
# ---
#
# ### 🧭 Interpretation of Coefficients
# - **β₀ (Intercept):** Baseline log-odds or probability when all features are zero.
# - **βᵢ (Feature Coefficient):**
#   - Represents the effect of feature \(x_i\) on the **log-odds** of the positive class.
#   - Positive βᵢ → Increases probability of class 1.
#   - Negative βᵢ → Decreases probability of class 1.

# %% [markdown]
# ## **Sigmoid Function, Decision Boundary, and Interpretation**
#
# ### 📈 **Sigmoid Function in Action**
# - The **sigmoid function** ensures outputs are **interpretable as probabilities**.
# - A **visualization of the sigmoid function** can illustrate how raw model predictions are mapped to probabilities between **0 and 1**.
#
# ### ✂️ **Decision Boundary**
# - The **default threshold** for classification is **0.5**.
# - **Adjusting the threshold** allows you to **balance precision and recall**, depending on the specific use case or performance requirements.

# %%
import numpy as np

a = -100
b = 100
np.random.seed(42)
X =   a + (b - a) * np.random.rand(100, 1)

y = 2 * X + 3

sigmoid = 1 / (1 + np.exp(-y))

# %%
X
# Out:
# array([[-25.09197623],
#        [ 90.14286128],
#        [ 46.39878836],
#        [ 19.73169684],
#        [-68.79627191],
#        [-68.80109593],
#        [-88.38327757],
#        [ 73.23522915],
#        [ 20.22300235],
#        [ 41.61451556],
#        [-95.88310114],
#        [ 93.98197043],
#        [ 66.48852816],
#        [-57.53217786],
#        [-63.63500656],
#        [-63.31909803],
#        [-39.15155141],
#        [  4.95128633],
#        [-13.61099627],
#        [-41.75417196],
#        [ 22.37057894],
#        [-72.10122787],
#        [-41.57107029],
#        [-26.72763134],
#        [ -8.78600316],
#        [ 57.03519228],
#        [-60.06524357],
#        [  2.84688768],
#        [ 18.48291377],
#        [-90.70991746],
#        [ 21.50897038],
#        [-65.89517526],
#        [-86.9896814 ],
#        [ 89.77710745],
#        [ 93.12640661],
#        [ 61.67946962],
#        [-39.07724617],
#        [-80.4655772 ],
#        [ 36.8466053 ],
#        [-11.96950125],
# ...

# %%
import matplotlib.pyplot as plt

plt.scatter(X, sigmoid, color = 'red', label = "Sigmoid based data")
plt.scatter(X, y, color = 'blue', label = " none Sigmoid based data")
plt.legend()
plt.show()

# %%
sigmoid
# Out:
# array([[3.22307055e-21],
#        [1.00000000e+00],
#        [1.00000000e+00],
#        [1.00000000e+00],
#        [3.52533922e-59],
#        [3.49149015e-59],
#        [3.42092826e-76],
#        [1.00000000e+00],
#        [1.00000000e+00],
#        [1.00000000e+00],
#        [1.04683921e-82],
#        [1.00000000e+00],
#        [1.00000000e+00],
#        [2.14322955e-49],
#        [1.07205986e-54],
#        [2.01657184e-54],
#        [1.97823543e-33],
#        [9.99997508e-01],
#        [3.02358581e-11],
#        [1.08560163e-35],
#        [1.00000000e+00],
#        [4.74845844e-62],
#        [1.56570730e-35],
#        [1.22337002e-22],
#        [4.69307899e-07],
#        [1.00000000e+00],
#        [1.35168587e-51],
#        [9.99832402e-01],
#        [1.00000000e+00],
#        [3.26024499e-78],
#        [1.00000000e+00],
#        [1.16697471e-56],
#        [5.55400433e-75],
#        [1.00000000e+00],
#        [1.00000000e+00],
#        [1.00000000e+00],
#        [2.29519025e-33],
# ...

# %%
z = np.linspace(-10, 10, 100)
sigmoid = 1 / (1 + np.exp(-z))
import matplotlib.pyplot as plt

plt.scatter(z, sigmoid, color = 'red', label = "Sigmoid based data")
plt.legend()
plt.show()

# %%
#################################### Exercise 1 ####################################
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, classification_report
from sklearn.model_selection import train_test_split
np.random.seed(42)
n_samples = 200
X = np.random.rand(n_samples, 2) * 10
y = (X[:,0] * 1.5 + X[:, 1] > 15).astype(int)

# %%
df = pd.DataFrame(X, columns=['Age', 'Salary'])
df['Purchase'] = y

# %%
X_train, X_test, y_train, y_test = train_test_split(df[['Age','Salary']], df['Purchase'], test_size=0.2, random_state=42)

# %%
model = LogisticRegression()

# %%
model.fit(X_train, y_train)
# Out:
# LogisticRegression()

# %%
y_pred = model.predict(X_test)

# %%
print("Acuracy:", accuracy_score(y_test, y_pred))
print("recall_score:", recall_score(y_test, y_pred))
print("f1_score:", f1_score(y_test, y_pred))
print("classification_report:", classification_report(y_test, y_pred))
print("precision_score:", precision_score(y_test, y_pred))
# Out:
# Acuracy: 1.0
# recall_score: 1.0
# f1_score: 1.0
# classification_report:               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        26
#            1       1.00      1.00      1.00        14
#
#     accuracy                           1.00        40
#    macro avg       1.00      1.00      1.00        40
# weighted avg       1.00      1.00      1.00        40
#
# precision_score: 1.0
